# %%
import mlcroissant as mlc
import hashlib
import os

# %%
network_list = ['1ramp', '2corridor', '3junction', '4smallRegion']

# %%
# 현재 작업 디렉토리 확인
current_path = os.getcwd()
current_path = current_path.replace("\\", "/")
print(f"Updated current_path: {current_path}")
# Out:
# Updated current_path: c:/Users/TLSYSLAB_3_ADMIN/Documents/Git/dataset

# %%
def sha256sum(file_path):
    with open(file_path, "rb") as f:
        return hashlib.sha256(f.read()).hexdigest()

sha_list = []
for net in network_list:
    sha_list.append(sha256sum(f'{current_path}/sensor_data/gt_edge_data_{net}-221014-from8to9.csv'))

# %% [markdown]
# # Distribution

# %%
distribution = [
    mlc.FileObject(
        id="bo-benchmark-repo",
        name="BO Benchmark Repository",
        description="GitHub repository containing SUMO network files and sensor measurements for Bayesian Optimization benchmarks.",
        content_url="https://github.com/TrafficSimBenchmark/dataset",
        encoding_formats=["git+https"],
        sha256="main",
    ),

    mlc.FileSet(
        id="network-files",
        name="Network Files",
        description="Each subfolder under 'network/' contains SUMO XML/CSV files for one specific traffic network.",
        contained_in=["bo-benchmark-repo"],
        encoding_formats=["application/xml", "text/csv"],
        includes="network/network1_SF_*/{additional.xml,net.xml,od.xml,routes.csv,taz.xml}",
    ),

    mlc.FileSet(
        id="sensor-csv-files",
        name="Sensor Data Files",
        description="Sensor ground-truth vehicle flow data for each network, stored as edge-wise CSV files.",
        contained_in=["bo-benchmark-repo"],
        encoding_formats=["text/csv"],
        includes="sensor_data/gt_edge_data_*.csv",
    ),

    # :::::::::: Individual sensor link flows csv files (FileObject) ::::::::::
    mlc.FileObject(
        id="sensor-1ramp",
        name="gt_edge_data_1ramp-221014-from8to9.csv",
        description="Sensor flow data for network 1ramp.",
        content_url="https://github.com/TrafficSimBenchmark/dataset/raw/main/sensor_data/gt_edge_data_1ramp-221014-from8to9.csv",
        encoding_formats=["text/csv"],
        sha256=sha_list[0],
        
    ),
    mlc.FileObject(
        id="sensor-2corridor",
        name="gt_edge_data_2corridor-221014-from8to9.csv",
        description="Sensor flow data for network 2corridor.",
        content_url="https://github.com/TrafficSimBenchmark/dataset/raw/main/sensor_data/gt_edge_data_2corridor-221014-from8to9.csv",
        encoding_formats=["text/csv"],
        sha256=sha_list[1],
    ),
    mlc.FileObject(
        id="sensor-3junction",
        name="gt_edge_data_3junction-221014-from8to9.csv",
        description="Sensor flow data for network 3junction.",
        content_url="https://github.com/TrafficSimBenchmark/dataset/raw/main/sensor_data/gt_edge_data_3junction-221014-from8to9.csv",
        encoding_formats=["text/csv"],
        sha256=sha_list[2],
    ),
    mlc.FileObject(
        id="sensor-4smallRegion",
        name="gt_edge_data_4smallRegion-221014-from8to9.csv",
        description="Sensor flow data for network 4smallRegion.",
        content_url="https://github.com/TrafficSimBenchmark/dataset/raw/main/sensor_data/gt_edge_data_4smallRegion-221014-from8to9.csv",
        encoding_formats=["text/csv"],
        sha256=sha_list[3],
    ),
]

# %% [markdown]
# # Record Sets

# %%
record_sets = []

for i, name in enumerate(["1ramp", "2corridor", "3junction", "4smallRegion"], start=1):
    file_id = f"sensor-{name}"
    file_path = f"sensor_data/gt_edge_data_{name}-221014-from8to9.csv"
    
    record_sets.append(
        mlc.RecordSet(
            id=f"sensor-records-{name}",
            name=f"Sensor Records - {name}",
            description=f"Sensor vehicle flow data for network {name}.",
            fields=[
                mlc.Field(
                    id=f"{name}-edge-id",
                    name="edge_id",
                    description="Edge ID where the sensor is located in the SUMO network.",
                    data_types=mlc.DataType.TEXT,
                    source=mlc.Source(
                        file_object=file_id,
                        extract=mlc.Extract(column="edge_id"),
                    ),
                ),
                mlc.Field(
                    id=f"{name}-flow",
                    name="interval_nVehContrib",
                    description="Number of vehicles that passed the sensor on this edge during the interval.",
                    data_types=mlc.DataType.INTEGER,
                    source=mlc.Source(
                        file_object=file_id,
                        extract=mlc.Extract(column="interval_nVehContrib"),
                    ),
                ),
            ]
        )
    )

# %% [markdown]
# # Meta Data

# %%
metadata = mlc.Metadata(
    name="BO Benchmark Dataset",
    description=(
        "This dataset contains four synthetic traffic networks modeled in SUMO "
        "along with corresponding vehicle flow measurements from virtual sensors. "
        "Each network has its own configuration files (network, OD, TAZ, etc.), and "
        "each has a matching CSV file listing vehicle flows on sensor-equipped edges."
    ),
    cite_as=(),
    url="https://github.com/TrafficSimBenchmark/dataset",          # 🔁 GitHub 실제 URL
    distribution=distribution,
    record_sets=record_sets,
)

# %% [markdown]
# # Check and Fix

# %%
print(metadata.issues.report())
# Out:
# Found the following 4 warning(s) during the validation:
#   -  [Metadata(BO Benchmark Dataset)] Property "http://mlcommons.org/croissant/citeAs" is recommended, but does not exist.
#   -  [Metadata(BO Benchmark Dataset)] Property "https://schema.org/datePublished" is recommended, but does not exist.
#   -  [Metadata(BO Benchmark Dataset)] Property "https://schema.org/license" is recommended, but does not exist.
#   -  [Metadata(BO Benchmark Dataset)] Property "https://schema.org/version" is recommended, but does not exist.

# %%
import json

with open("croissant.json", "w") as f:
  content = metadata.to_json()
  content = json.dumps(content, indent=2)
  print(content)
  f.write(content)
  f.write("\n")  # Terminate file with newline
# Out:
# {
#   "@context": {
#     "@language": "en",
#     "@vocab": "https://schema.org/",
#     "citeAs": "cr:citeAs",
#     "column": "cr:column",
#     "conformsTo": "dct:conformsTo",
#     "cr": "http://mlcommons.org/croissant/",
#     "rai": "http://mlcommons.org/croissant/RAI/",
#     "data": {
#       "@id": "cr:data",
#       "@type": "@json"
#     },
#     "dataType": {
#       "@id": "cr:dataType",
#       "@type": "@vocab"
#     },
#     "dct": "http://purl.org/dc/terms/",
#     "examples": {
#       "@id": "cr:examples",
#       "@type": "@json"
#     },
#     "extract": "cr:extract",
#     "field": "cr:field",
#     "fileProperty": "cr:fileProperty",
#     "fileObject": "cr:fileObject",
#     "fileSet": "cr:fileSet",
#     "format": "cr:format",
#     "includes": "cr:includes",
#     "isLiveDataset": "cr:isLiveDataset",
#     "jsonPath": "cr:jsonPath",
#     "key": "cr:key",
#     "md5": "cr:md5",
#     "parentField": "cr:parentField",
#     "path": "cr:path",
#     "recordSet": "cr:recordSet",
#     "references": "cr:references",
#     "regex": "cr:regex",
#     "repeated": "cr:repeated",
#     "replace": "cr:replace",
#     "sc": "https://schema.org/",
#     "separator": "cr:separator",
#     "source": "cr:source",
#     "subField": "cr:subField",
#     "transform": "cr:transform"
#   },
#   "@type": "sc:Dataset",
#   "name": "BO Benchmark Dataset",
#   "description": "This dataset contains four synthetic traffic networks modeled in SUMO along with corresponding vehicle flow measurements from virtual sensors. Each network has its own configuration files (network, OD, TAZ, etc.), and each has a matching CSV file listing vehicle flows on sensor-equipped edges.",
#   "conformsTo": "http://mlcommons.org/croissant/1.0",
#   "url": "https://github.com/TrafficSimBenchmark/dataset",
#   "distribution": [
#     {
#       "@type": "cr:FileObject",
#       "@id": "bo-benchmark-repo",
#       "name": "BO Benchmark Repository",
#       "description": "GitHub repository containing SUMO network files and sensor measurements for Bayesian Optimization benchmarks.",
#       "contentUrl": "https://github.com/TrafficSimBenchmark/dataset",
#       "encodingFormat": "git+https",
#       "sha256": "main"
#     },
#     {
#       "@type": "cr:FileSet",
#       "@id": "network-files",
#       "name": "Network Files",
#       "description": "Each subfolder under 'network/' contains SUMO XML/CSV files for one specific traffic network.",
#       "containedIn": {
#         "@id": "bo-benchmark-repo"
#       },
#       "encodingFormat": [
#         "application/xml",
#         "text/csv"
#       ],
#       "includes": "network/network1_SF_*/{additional.xml,net.xml,od.xml,routes.csv,taz.xml}"
#     },
#     {
#       "@type": "cr:FileSet",
#       "@id": "sensor-csv-files",
#       "name": "Sensor Data Files",
#       "description": "Sensor ground-truth vehicle flow data for each network, stored as edge-wise CSV files.",
#       "containedIn": {
#         "@id": "bo-benchmark-repo"
#       },
#       "encodingFormat": "text/csv",
#       "includes": "sensor_data/gt_edge_data_*.csv"
#     },
#     {
#       "@type": "cr:FileObject",
#       "@id": "sensor-1ramp",
#       "name": "gt_edge_data_1ramp-221014-from8to9.csv",
#       "description": "Sensor flow data for network 1ramp.",
#       "contentUrl": "https://github.com/TrafficSimBenchmark/dataset/raw/main/sensor_data/gt_edge_data_1ramp-221014-from8to9.csv",
#       "encodingFormat": "text/csv",
#       "sha256": "79b955e6749c113566ce7eaca467ab76de46482b3edc7e855b17b2eee35a07f6"
#     },
#     {
#       "@type": "cr:FileObject",
#       "@id": "sensor-2corridor",
#       "name": "gt_edge_data_2corridor-221014-from8to9.csv",
#       "description": "Sensor flow data for network 2corridor.",
#       "contentUrl": "https://github.com/TrafficSimBenchmark/dataset/raw/main/sensor_data/gt_edge_data_2corridor-221014-from8to9.csv",
#       "encodingFormat": "text/csv",
#       "sha256": "31f281bb177ced3c2a54c92a83090e9bf8ac938032ccb2c99796ad97e785382a"
#     },
#     {
#       "@type": "cr:FileObject",
#       "@id": "sensor-3junction",
#       "name": "gt_edge_data_3junction-221014-from8to9.csv",
#       "description": "Sensor flow data for network 3junction.",
#       "contentUrl": "https://github.com/TrafficSimBenchmark/dataset/raw/main/sensor_data/gt_edge_data_3junction-221014-from8to9.csv",
#       "encodingFormat": "text/csv",
#       "sha256": "fabe508348d92484199ff9a90c191b26396b9272fed6910adadba8c2cd0399b0"
#     },
#     {
#       "@type": "cr:FileObject",
#       "@id": "sensor-4smallRegion",
#       "name": "gt_edge_data_4smallRegion-221014-from8to9.csv",
#       "description": "Sensor flow data for network 4smallRegion.",
#       "contentUrl": "https://github.com/TrafficSimBenchmark/dataset/raw/main/sensor_data/gt_edge_data_4smallRegion-221014-from8to9.csv",
#       "encodingFormat": "text/csv",
#       "sha256": "811d35019e484d0b5eee2d2280041c5a0f436f7082055b2d3f3e3d7c9c277ade"
#     }
#   ],
#   "recordSet": [
#     {
#       "@type": "cr:RecordSet",
#       "@id": "sensor-records-1ramp",
#       "name": "Sensor Records - 1ramp",
#       "description": "Sensor vehicle flow data for network 1ramp.",
#       "field": [
#         {
#           "@type": "cr:Field",
#           "@id": "1ramp-edge-id",
#           "name": "edge_id",
#           "description": "Edge ID where the sensor is located in the SUMO network.",
#           "dataType": "sc:Text",
#           "source": {
#             "fileObject": {
#               "@id": "sensor-1ramp"
#             },
#             "extract": {
#               "column": "edge_id"
#             }
#           }
#         },
#         {
#           "@type": "cr:Field",
#           "@id": "1ramp-flow",
#           "name": "interval_nVehContrib",
#           "description": "Number of vehicles that passed the sensor on this edge during the interval.",
#           "dataType": "sc:Integer",
#           "source": {
#             "fileObject": {
#               "@id": "sensor-1ramp"
#             },
#             "extract": {
#               "column": "interval_nVehContrib"
#             }
#           }
#         }
#       ]
#     },
#     {
#       "@type": "cr:RecordSet",
#       "@id": "sensor-records-2corridor",
#       "name": "Sensor Records - 2corridor",
#       "description": "Sensor vehicle flow data for network 2corridor.",
#       "field": [
#         {
#           "@type": "cr:Field",
#           "@id": "2corridor-edge-id",
#           "name": "edge_id",
#           "description": "Edge ID where the sensor is located in the SUMO network.",
#           "dataType": "sc:Text",
#           "source": {
#             "fileObject": {
#               "@id": "sensor-2corridor"
#             },
#             "extract": {
#               "column": "edge_id"
#             }
#           }
#         },
#         {
#           "@type": "cr:Field",
#           "@id": "2corridor-flow",
#           "name": "interval_nVehContrib",
#           "description": "Number of vehicles that passed the sensor on this edge during the interval.",
#           "dataType": "sc:Integer",
#           "source": {
#             "fileObject": {
#               "@id": "sensor-2corridor"
#             },
#             "extract": {
#               "column": "interval_nVehContrib"
#             }
#           }
#         }
#       ]
#     },
#     {
#       "@type": "cr:RecordSet",
#       "@id": "sensor-records-3junction",
#       "name": "Sensor Records - 3junction",
#       "description": "Sensor vehicle flow data for network 3junction.",
#       "field": [
#         {
#           "@type": "cr:Field",
#           "@id": "3junction-edge-id",
#           "name": "edge_id",
#           "description": "Edge ID where the sensor is located in the SUMO network.",
#           "dataType": "sc:Text",
#           "source": {
#             "fileObject": {
#               "@id": "sensor-3junction"
#             },
#             "extract": {
#               "column": "edge_id"
#             }
#           }
#         },
#         {
#           "@type": "cr:Field",
#           "@id": "3junction-flow",
#           "name": "interval_nVehContrib",
#           "description": "Number of vehicles that passed the sensor on this edge during the interval.",
#           "dataType": "sc:Integer",
#           "source": {
#             "fileObject": {
#               "@id": "sensor-3junction"
#             },
#             "extract": {
#               "column": "interval_nVehContrib"
#             }
#           }
#         }
#       ]
#     },
#     {
#       "@type": "cr:RecordSet",
#       "@id": "sensor-records-4smallRegion",
#       "name": "Sensor Records - 4smallRegion",
#       "description": "Sensor vehicle flow data for network 4smallRegion.",
#       "field": [
#         {
#           "@type": "cr:Field",
#           "@id": "4smallRegion-edge-id",
#           "name": "edge_id",
#           "description": "Edge ID where the sensor is located in the SUMO network.",
#           "dataType": "sc:Text",
#           "source": {
#             "fileObject": {
#               "@id": "sensor-4smallRegion"
#             },
#             "extract": {
#               "column": "edge_id"
#             }
#           }
#         },
#         {
#           "@type": "cr:Field",
#           "@id": "4smallRegion-flow",
#           "name": "interval_nVehContrib",
#           "description": "Number of vehicles that passed the sensor on this edge during the interval.",
#           "dataType": "sc:Integer",
#           "source": {
#             "fileObject": {
#               "@id": "sensor-4smallRegion"
#             },
#             "extract": {
#               "column": "interval_nVehContrib"
#             }
#           }
#         }
#       ]
#     }
#   ]
# }

# %%
dataset = mlc.Dataset(jsonld="croissant.json")
# Out:
# WARNING:absl:Found the following 4 warning(s) during the validation:
#   -  [Metadata(BO Benchmark Dataset)] Property "http://mlcommons.org/croissant/citeAs" is recommended, but does not exist.
#   -  [Metadata(BO Benchmark Dataset)] Property "https://schema.org/datePublished" is recommended, but does not exist.
#   -  [Metadata(BO Benchmark Dataset)] Property "https://schema.org/license" is recommended, but does not exist.
#   -  [Metadata(BO Benchmark Dataset)] Property "https://schema.org/version" is recommended, but does not exist.

# %%
records = dataset.records(record_set="sensor-records-1ramp")

for i, record in enumerate(records):
  print(record)
  if i > 10:
    break
# Out:
# Downloading https://github.com/TrafficSimBenchmark/dataset/raw/main/sensor_data/gt_edge_data_1ramp-221014-from8to9.csv...:  88%|████████▊ | 75.0/85.0 [00:00<?, ?iB/s]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File c:\Users\TLSYSLAB_3_ADMIN\anaconda3\envs\langchain_env\Lib\site-packages\mlcroissant\_src\operation_graph\execute.py:119, in execute_operations_in_streaming(record_set, operations, list_of_operations, result)
#     118         logging.info("Executing %s", operation)
# --> 119         result = operation.call(result)
#     120 except Exception as e:
#
# File c:\Users\TLSYSLAB_3_ADMIN\anaconda3\envs\langchain_env\Lib\site-packages\mlcroissant\_src\operation_graph\operations\download.py:233, in Download.call(***failed resolving arguments***)
#     232         self._download_from_http(filepath)
# --> 233 self._check_hash(filepath)
#     234 logging.info(
#     235     "File %s is downloaded to %s", self.node.content_url, os.fspath(filepath)
#     236 )
#
# File c:\Users\TLSYSLAB_3_ADMIN\anaconda3\envs\langchain_env\Lib\site-packages\mlcroissant\_src\operation_graph\operations\download.py:179, in Download._check_hash(self, filepath)
#     178 if not ctx.is_v0():
# --> 179     raise ValueError(
#     180         f"Hash of downloaded file {filepath} is not identical with the"
#     181         f" reference in the Croissant JSON-LD. Expected: {expected_hash} -"
#     182         f" Got: {hex_hash} (hex) / {base64_hash} (base64)"
#     183     )
#
# ValueError: Hash of downloaded file C:\Users\TLSYSLAB_3_ADMIN\.cache\croissant\download\croissant-3ca415f9e3ccfb49cecbef53e7ed49c43a3581f679c18095b97a8d8e3ddc2771 is not identical with the reference in the Croissant JSON-LD. Expected: 79b955e6749c113566ce7eaca467ab76de46482b3edc7e855b17b2eee35a07f6 - Got: f1d2da511bf6dc3bc1a941ff751dbb02ca2789dafe4b24efc663218020d84569 (hex) / 8dLaURv23DvBqUH/dR27Asonidr+SyTvxmMhgCDYRWk= (base64)
#
# The above exception was the direct cause of the following exception:
#
# GenerationError                           Traceback (most recent call last)
# Cell In[15], line 3
#       1 records = dataset.records(record_set="sensor-records-1ramp")
# ----> 3 for i, record in enumerate(records):
#       4   print(record)
#       5   if i > 10:
#
# File c:\Users\TLSYSLAB_3_ADMIN\anaconda3\envs\langchain_env\Lib\site-packages\mlcroissant\_src\datasets.py:166, in Records.__iter__(self)
#     161 # We can stream the dataset iff the operation graph is a path graph (meaning
#     162 # that all operations lie on a single straight line, i.e. have an
#     163 # in-degree of 0 or 1. That means that the operation graph is a single line
#     164 # (without external joins for example).
#     165 if _is_streamable_dataset(operations):
# --> 166     yield from execute_operations_in_streaming(
#     167         record_set=self.record_set,
#     168         operations=operations,
#     169     )
#     170 else:
#     171     yield from execute_operations_sequentially(
#     172         record_set=self.record_set, operations=operations
#     173     )
#
# File c:\Users\TLSYSLAB_3_ADMIN\anaconda3\envs\langchain_env\Lib\site-packages\mlcroissant\_src\operation_graph\execute.py:121, in execute_operations_in_streaming(record_set, operations, list_of_operations, result)
#     119         result = operation.call(result)
#     120 except Exception as e:
# --> 121     raise GenerationError(
#     122         "An error occured during the streaming generation of the dataset, more"
#     123         f" specifically during the operation {operation}"
#     124     ) from e
#
# GenerationError: An error occured during the streaming generation of the dataset, more specifically during the operation Download(sensor-1ramp)
